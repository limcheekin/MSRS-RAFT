# %% [markdown]
# ## Setup

# %%
# 1. Clone the repository
# !git clone https://github.com/limcheekin/MSRS-RAFT

# 2. Move into the project directory
# %cd MSRS-RAFT

# 3. Install Git LFS and pull the large files
# This is the new, critical step
# !sudo apt-get install git-lfs
# !git lfs pull

# 4. Install Python dependencies
# !pip install -r requirements.txt
# !pip install --upgrade --force-reinstall --no-cache-dir unsloth unsloth_zoo -q
# !pip install huggingface_hub -q

# 5. Download NLTK data (for evaluation metrics)
# !python -c "import nltk; nltk.download('punkt')"
# Out:
# fatal: destination path 'MSRS-RAFT' already exists and is not an empty directory.
# /content/MSRS-RAFT
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-2a_osat4/unsloth_80ad65b89f874c87b9354c3eee38463c
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-2a_osat4/unsloth_80ad65b89f874c87b9354c3eee38463c
#   Resolved https://github.com/unslothai/unsloth.git to commit d707bd43b4e883b521761d525be2fae428fe5980
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 149.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Set HF_TOKEN

# %%
from google.colab import userdata
import os

hf_token = userdata.get('huggingface')
os.environ['HF_TOKEN'] = hf_token

# %% [markdown]
# ## Run Evaluation

# %%
# 1. VERY IMPORTANT: Verify the files exist
# If this command shows "No such file or directory", your LFS pull failed.
# !ls -lh ./data/raft_test.jsonl ./indices/raft_index.faiss

# 2. Run your valid evaluation command
# This command is correct.
# !python raft_pipeline.py \
  --step eval \
  --config raft_config.yaml \
  --model-path "limcheekin/RAFT-Qwen3-4B-Instruct-2507-v0.1" \
  --split "test" \
  --eval-max-examples 20
# Out:
# -rw-r--r-- 1 root root 1.1M Nov  3 08:08 ./data/raft_test.jsonl
# -rw-r--r-- 1 root root 4.6M Nov  3 08:08 ./indices/raft_index.faiss
# 2025-11-03 08:34:56.714601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762158896.736083    8248 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762158896.743177    8248 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762158896.761212    8248 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
